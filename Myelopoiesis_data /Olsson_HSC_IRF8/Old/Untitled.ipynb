# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import scanpy as sc
import matplotlib.colors as mplcol
import matplotlib.font_manager
import matplotlib as mpl
import io
import anndata
from matplotlib import rcParams

# %%
import scanpy as sc

# %%
adata = sc.read_h5ad('Olsson.h5ad')

# %%
adata
# Out:
# AnnData object with n_obs × n_vars = 675 × 9745
#     obs: 'Dataset_Info_Dataset_Accession_Number', 'Sample_Accession_Number', 'Organism', 'Organ', 'Developmental_Stage', 'Cell_Type', 'Sequencer', 'Protocol', 'Assay_Type', 'Library_Layout', 'Ontology_Term', 'Cell_Cycle_Phase', 'n_counts'
#     var: 'Gene name', 'Gene % GC content', 'highly_variable', 'means', 'dispersions', 'dispersions_norm', 'mean', 'std'
#     uns: 'Cell_Type_colors', 'Organ_colors', 'hvg', 'neighbors', 'pca', 'umap'
#     obsm: 'X_pca', 'X_tsne', 'X_umap'
#     varm: 'PCs'
#     obsp: 'connectivities', 'distances'

# %%
adata.obs
# Out:
#            Dataset_Info_Dataset_Accession_Number Sample_Accession_Number  \
# SRR2077088                              GSE70245            SAMN03792848
# SRR2077089                              GSE70245            SAMN03792849
# SRR2077090                              GSE70245            SAMN03792850
# SRR2077091                              GSE70245            SAMN03792851
# SRR2077092                              GSE70245            SAMN03792852
# ...                                          ...                     ...
# SRR3203979                              GSE70245            SAMN04532097
# SRR3203980                              GSE70245            SAMN04532098
# SRR3203981                              GSE70245            SAMN04532099
# SRR3203982                              GSE70245            SAMN04532100
# SRR3203983                              GSE70245            SAMN04532101
#
#                 Organism        Organ Developmental_Stage  \
# SRR2077088  Mus musculus  Bone marrow               Adult
# SRR2077089  Mus musculus  Bone marrow               Adult
# SRR2077090  Mus musculus  Bone marrow               Adult
# SRR2077091  Mus musculus  Bone marrow               Adult
# SRR2077092  Mus musculus  Bone marrow               Adult
# ...                  ...          ...                 ...
# SRR3203979  Mus musculus  Bone marrow               Adult
# SRR3203980  Mus musculus  Bone marrow               Adult
# SRR3203981  Mus musculus  Bone marrow               Adult
# SRR3203982  Mus musculus  Bone marrow               Adult
# SRR3203983  Mus musculus  Bone marrow               Adult
#
#                       Cell_Type            Sequencer Protocol Assay_Type  \
# SRR2077088  Myeloid progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR2077089  Myeloid progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR2077090  Myeloid progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR2077091  Myeloid progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR2077092  Myeloid progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# ...                         ...                  ...      ...        ...
# SRR3203979      GMP Progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR3203980      GMP Progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR3203981      GMP Progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR3203982      GMP Progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
# SRR3203983      GMP Progenitors  Illumina HiSeq 2500  SMARTer    RNA-Seq
#
#            Library_Layout                                      Ontology_Term  \
# SRR2077088     Paired-end                          CL:0000763 [Myeloid cell]
# SRR2077089     Paired-end                          CL:0000763 [Myeloid cell]
# SRR2077090     Paired-end                          CL:0000763 [Myeloid cell]
# SRR2077091     Paired-end                          CL:0000763 [Myeloid cell]
# SRR2077092     Paired-end                          CL:0000763 [Myeloid cell]
# ...                   ...                                                ...
# SRR3203979     Paired-end  OMIT:0026108 [Granulocyte-Macrophage Progenito...
# SRR3203980     Paired-end  OMIT:0026108 [Granulocyte-Macrophage Progenito...
# SRR3203981     Paired-end                          CL:0000763 [Myeloid cell]
# SRR3203982     Paired-end                          CL:0000763 [Myeloid cell]
# SRR3203983     Paired-end                          CL:0000763 [Myeloid cell]
#
#            Cell_Cycle_Phase       n_counts
# SRR2077088             G2.M  363315.843750
# SRR2077089             M.G1  276883.187500
# SRR2077090             M.G1  744888.062500
# SRR2077091             M.G1  317276.812500
# SRR2077092             M.G1  274052.000000
# ...                     ...            ...
# SRR3203979                S  254197.765625
# SRR3203980                S  262087.750000
# SRR3203981             G2.M  289098.531250
# SRR3203982                S  292338.187500
# SRR3203983                S  332850.343750
#
# [675 rows x 13 columns]
